# %%
cd ..

# %%
sbt "dependencyList"
# Out:
# Java HotSpot(TM) 64-Bit Server VM warning: ignoring option MaxPermSize=384m; support was removed in 8.0
# [info] Loading project definition from /Users/sakamoto/Documents/FelisCatusZero/project
# [info] Set current project to FelisCatusZero (in build file:/Users/sakamoto/Documents/FelisCatusZero/)
# [info] aopalliance:aopalliance:1.0
# [info] args4j:args4j:2.32
# [info] axis:axis:1.3
# [info] axis:axis-jaxrpc:1.3
# [info] axis:axis-saaj:1.3
# [info] com.apple:AppleJavaExtensions:1.4
# [info] com.google.protobuf:protobuf-java:2.6.1
# [info] com.googlecode.efficient-java-matrix-library:ejml:0.23
# [info] com.iheart:ficus_2.12:1.4.0
# [info] com.io7m.xom:xom:1.2.10
# [info] com.typesafe:config:1.3.1
# [info] commons-cli:commons-cli:1.3.1
# [info] commons-codec:commons-codec:1.2
# [info] commons-discovery:commons-discovery:0.2
# [info] commons-httpclient:commons-httpclient:3.1
# [info] commons-io:commons-io:2.2
# [info] commons-lang:commons-lang:2.6
# ...

# %%
sbt "dependencyTree"
# Out:
# Java HotSpot(TM) 64-Bit Server VM warning: ignoring option MaxPermSize=384m; support was removed in 8.0
# [info] Loading project definition from /Users/sakamoto/Documents/FelisCatusZero/project
# [info] Set current project to FelisCatusZero (in build file:/Users/sakamoto/Documents/FelisCatusZero/)
# [info] default:feliscatuszero_2.12:0.0.1 [S]
# [info]   +-args4j:args4j:2.32
# [info]   +-com.iheart:ficus_2.12:1.4.0 [S]
# [info]   | +-com.typesafe:config:1.3.1
# [info]   | +-org.typelevel:macro-compat_2.12:1.1.1 [S]
# [info]   |
# [info]   +-com.typesafe:config:1.3.0 (evicted by: 1.3.1)
# [info]   +-com.typesafe:config:1.3.1
# [info]   +-commons-cli:commons-cli:1.3.1
# [info]   +-edu.stanford.nlp:stanford-corenlp:3.7.0
# [info]   | +-com.apple:AppleJavaExtensions:1.4
# [info]   | +-com.google.protobuf:protobuf-java:2.6.1
# [info]   | +-com.googlecode.efficient-java-matrix-library:ejml:0.23
# [info]   | +-com.io7m.xom:xom:1.2.10
# [info]   | | +-xalan:xalan:2.7.0
# ...

# %%
sbt "dependencyBrowseGraph"
# Out:
# Java HotSpot(TM) 64-Bit Server VM warning: ignoring option MaxPermSize=384m; support was removed in 8.0
# [info] Loading project definition from /Users/sakamoto/Documents/FelisCatusZero/project
# [info] Set current project to FelisCatusZero (in build file:/Users/sakamoto/Documents/FelisCatusZero/)
# [info] HTML graph written to file:/Users/sakamoto/Documents/FelisCatusZero/target/browse-dependency-graph/graph.html
# [info] Opening in browser...
# [success] Total time: 0 s, completed Feb 20, 2017 5:21:49 AM

# %% [markdown]
# Browse the dependency graph in the default web browser as below<br>
# <img src="image/dependencyGraph.png"/>
