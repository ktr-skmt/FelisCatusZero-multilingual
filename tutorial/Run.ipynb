# %%
cd ..

# %% [markdown]
# You have to run the whole pipeline at first as below.

# %%
sbt "run-main uima.cpe.CPERunner"
# Out:
# Java HotSpot(TM) 64-Bit Server VM warning: ignoring option MaxPermSize=384m; support was removed in 8.0
# [info] Loading project definition from /Users/sakamoto/Documents/FelisCatusZero/project
# [info] Set current project to FelisCatusZero (in build file:/Users/sakamoto/Documents/FelisCatusZero/)
# [info] Compiling 401 Scala sources and 66 Java sources to /Users/sakamoto/Documents/FelisCatusZero/target/scala-2.12/classes...
# [info] Running uima.cpe.CPERunner
# [info] >> Converting from QA Lab Dataset to Multilingual QA Corpus
# [info] >> Collection Processing Engine Processing
# [info] >> Flow Controller Initializing
# [info] >> Question Analyzer Flow Controller Initializing
# [info] >> Information Retriever Flow Controller Initializing
# [info] Collection Processing Engine:
# [info] * cpeDescriptor.xml
# [info] Flow Controller Analysis Engine List:
# [info] 1. questionAnalyzerAAEDescriptor
# [info] 2. informationRetrieverAAEDescriptor
# [info] 3. essayGeneratorAAEDescriptor
# ...

# %% [markdown]
# <p>Once the run finished, browse evaluation results in the default web browswer.</p>
# <p>Show Japanese essay evaluation results as below</p>
# <img src="image/whole_pipeline_result_1.png"/><br>
# <p>Show English essay evaluation results as below</p>
# <img src="image/whole_pipeline_result_2.png"/><br>
# <p>Click the "HISTORY" link</p>
# <img src="image/whole_pipeline_history.png"/>

# %% [markdown]
# If you want to run a part of pipeline (pipeline from Essay Generator), do as below.

# %%
sbt "run-main uima.cpe.CPERunner -from eg"
# Out:
# Java HotSpot(TM) 64-Bit Server VM warning: ignoring option MaxPermSize=384m; support was removed in 8.0
# [info] Loading project definition from /Users/sakamoto/Documents/FelisCatusZero/project
# [info] Set current project to FelisCatusZero (in build file:/Users/sakamoto/Documents/FelisCatusZero/)
# [info] Running uima.cpe.CPERunner -from eg
# [info] >> Converting from QA Lab Dataset to Multilingual QA Corpus
# [info] >> Collection Processing Engine Processing
# [info] >> Flow Controller Initializing
# [info] Collection Processing Engine:
# [info] * cpeFromIntermediatePointDescriptor.xml
# [info] Flow Controller Analysis Engine List:
# [info] 1. essayGeneratorAAEDescriptor
# [info] Question Analyzer Flow Controller Analysis Engine List:
# [info] (empty)
# [info] Information Retriever Flow Controller Analysis Engine List:
# [info] (empty)
# [info] Essay Generator Flow Controller Analysis Engine List:
# [info] 1. essayGeneratorAEDescriptor
# [info] 2. gzipXmiCasConsumerDescriptor
# ...

# %% [markdown]
# <p>Once the run finished, browse evaluation results in the default web browswer.</p>
# <p>Show Japanese essay evaluation results as below</p>
# <img src="image/part_of_pipeline_result_1.png"/><br>
# <p>Show English essay evaluation results as below</p>
# <img src="image/part_of_pipeline_result_2.png"/><br>
# <p>Click the "HISTORY" link</p>
# <img src="image/part_of_pipeline_history.png"/>
