# %%
cd ..

# %%
sbt "run-main util.JCasGen"
# Out:
# Java HotSpot(TM) 64-Bit Server VM warning: ignoring option MaxPermSize=384m; support was removed in 8.0
# [info] Loading project definition from /Users/sakamoto/Documents/FelisCatusZero/project
# [info] Set current project to FelisCatusZero (in build file:/Users/sakamoto/Documents/FelisCatusZero/)
# [info] Compiling 66 Java sources to /Users/sakamoto/Documents/FelisCatusZero/target/scala-2.12/classes...
# [info] Running util.JCasGen
# [error] Feb 20, 2017 5:29:01 AM org.apache.uima.tools.jcasgen.UimaLoggerProgressMonitor subTask(35)
# [error] INFO:  >>JCasGen Replacing: 'org.apache.uima.examples.SourceDocumentInformation'.
# [error] Feb 20, 2017 5:29:01 AM org.apache.uima.tools.jcasgen.UimaLoggerProgressMonitor subTask(35)
# [error] INFO:  >>JCasGen Replacing: 'org.apache.uima.examples.SourceDocumentInformation_Type'.
# [error] Feb 20, 2017 5:29:01 AM org.apache.uima.tools.jcasgen.UimaLoggerProgressMonitor subTask(35)
# ...
